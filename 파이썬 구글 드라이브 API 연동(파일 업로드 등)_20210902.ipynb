# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import os
from googleapiclient.discovery import build
from httplib2 import Http
from oauth2client import file, client, tools
from googleapiclient.http import MediaFileUpload
from __future__ import print_function
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

SCOPES = ['https://www.googleapis.com/auth/drive']

def main():
    """Shows basic usage of the Drive v3 API.
    Prints the names and ids of the first 10 files the user has access to.
    """
    creds = None
    # The file token.pickle stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)

    service = build('drive', 'v3', credentials=creds)

    # Call the Drive v3 API
    results = service.files().list(
        pageSize=10, fields="nextPageToken, files(id, name)").execute()
    items = results.get('files', [])

    if not items:
        print('No files found.')
    else:
        print('Files:')
        for item in items:
            print(u'{0} ({1})'.format(item['name'], item['id']))

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-cdee12ae3d45> in <module>
#      53
#      54 if __name__ == '__main__':
# ---> 55     main()
#
# <ipython-input-21-cdee12ae3d45> in main()
#      31             creds.refresh(Request())
#      32         else:
# ---> 33             flow = InstalledAppFlow.from_client_secrets_file(
#      34                 'credentials.json', SCOPES)
#      35             creds = flow.run_local_server(port=0)
#
# c:\users\gravity\appdata\local\programs\python\python39\lib\site-packages\google_auth_oauthlib\flow.py in from_client_secrets_file(cls, client_secrets_file, scopes, **kwargs)
#     201             Flow: The constructed Flow instance.
#     202         """
# --> 203         with open(client_secrets_file, "r") as json_file:
#     204             client_config = json.load(json_file)
#     205
#
# ...

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import os
from googleapiclient.discovery import build
from httplib2 import Http
from oauth2client import file, client, tools
from googleapiclient.http import MediaFileUpload
from __future__ import print_function
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import  warnings
from    selenium import webdriver
from    selenium.webdriver.common.keys import Keys 
from    selenium.webdriver.common.action_chains import ActionChains
from    selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException
from    bs4      import BeautifulSoup
import  time
import  pyperclip
import  requests
import  datetime
import  pymssql
import  pandas as pd
import  chromedriver_autoinstaller
import  subprocess
from    selenium import webdriver
from    selenium.webdriver.chrome.options import Options
from    selenium.webdriver.common.alert import Alert
import  chromedriver_autoinstaller
import  subprocess
import  shutil 
import  xlrd
import  openpyxl 
import  pygsheets

scope = [
'https://spreadsheets.google.com/feeds',
'https://www.googleapis.com/auth/drive']

json_file_name = 'C:/Users/Gravity/Desktop/python/python-linkage-sample-324706-63cfc05b9800.json'

credentials = ServiceAccountCredentials.from_json_keyfile_name(json_file_name, scope)
gc = gspread.authorize(credentials)

ragnarok_cash_daily_url = 'https://docs.google.com/spreadsheets/d/1gTtQZ1zEEm6lJ2nQysQfbzPU6wilUZRBqiGI-eaXSPo/edit#gid=0' #URL 지정

ragnarok_cash_daily_google_docs = gc.open_by_url(ragnarok_cash_daily_url) #url 열기

zeny_quote_worksheet = ragnarok_cash_daily_google_docs.worksheet('제니시세') #worksheet 선택
zeny_trade_worksheet = ragnarok_cash_daily_google_docs.worksheet('제니거래량') #worksheet 선택

zeny_quote_worksheet_data = zeny_quote_worksheet.get_all_values() #제니시세 데이터 가져오기
zeny_trade_worksheet_data = zeny_trade_worksheet.get_all_values() #제니거래량 데이터 가져오기

zeny_quote_summary_csv = pd.read_csv('C:/Users/Gravity/Desktop/python/raw/statistics/zeny_quote_summary_20210902.csv')
zeny_trade_cash_summary_csv = pd.read_csv('C:/Users/Gravity/Desktop/python/raw/statistics/zeny_trade_cash_summary_20210902.csv')



"""
# 스프레스시트 문서 가져오기 
doc1 = gc.open_by_url(ragnarok_cash_url)
doc2 = gc.open_by_url(zeny_quote_summary_url)

worksheet = doc1.worksheet('시트1')

print(worksheet)
"""
# Out:
# "\n# 스프레스시트 문서 가져오기 \ndoc1 = gc.open_by_url(ragnarok_cash_url)\ndoc2 = gc.open_by_url(zeny_quote_summary_url)\n\nworksheet = doc1.worksheet('시트1')\n\nprint(worksheet)\n"

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import os
from googleapiclient.discovery import build
from httplib2 import Http
from oauth2client import file, client, tools
from googleapiclient.http import MediaFileUpload
from __future__ import print_function
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import  warnings
from    selenium import webdriver
from    selenium.webdriver.common.keys import Keys 
from    selenium.webdriver.common.action_chains import ActionChains
from    selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException
from    bs4      import BeautifulSoup
import  time
import  pyperclip
import  requests
import  datetime
import  pymssql
import  pandas as pd
import  chromedriver_autoinstaller
import  subprocess
from    selenium import webdriver
from    selenium.webdriver.chrome.options import Options
from    selenium.webdriver.common.alert import Alert
import  chromedriver_autoinstaller
import  subprocess
import  shutil 
import  xlrd
import  openpyxl 
import  pygsheets
import  csv

json_file_name = 'C:/Users/Gravity/Desktop/python/python-linkage-sample-324706-63cfc05b9800.json'

scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/spreadsheets', 
         'https://www.googleapis.com/auth/drive.file', 'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name(json_file_name, scope)
gc = gspread.authorize(credentials)

cash_daily_url = 'https://docs.google.com/spreadsheets/d/1gTtQZ1zEEm6lJ2nQysQfbzPU6wilUZRBqiGI-eaXSPo/edit#gid=0' # 제니시세 url 
cash_trade_url = 'https://docs.google.com/spreadsheets/d/1gTtQZ1zEEm6lJ2nQysQfbzPU6wilUZRBqiGI-eaXSPo/edit#gid=10285227' #제니거래량 url 

cash_daily_url_2 = gc.open_by_url(cash_daily_url) #제니시세 구글독스 열기
cash_daily_url_2_worksheet = cash_daily_url_2.worksheet('제니시세') #제니시세 시트 열기

cash_trade_url_2 = gc.open_by_url(cash_trade_url) #제니거래량 구글독스 열기
cash_trade_url_2_worksheet = cash_trade_url_2.worksheet('제니거래량') #제니거래량 시트 열기

cash_daily_data = cash_daily_url_2_worksheet.get_all_values() #제니시세 구글독스 시트내 데이터 가져오기
cash_trade_data = cash_trade_url_2_worksheet.get_all_values() #제니시세 구글독스 시트내 데이터 가져오기

zeny_quote_lists = [] #제니시세 엑셀파일 리스트에 담기
zeny_quote_file = open('C:/Users/Gravity/Desktop/python/raw/statistics/zeny_quote_summary_20210902.csv', 'r', encoding ='utf-8-sig', newline='\n')

zeny_trade_cash_lists = [] #제니거래량 엑셀파일 리스트에 담기
zeny_trade_cash_file = open('C:/Users/Gravity/Desktop/python/raw/statistics/zeny_trade_cash_summary_20210902.csv', 'r', encoding ='utf-8-sig', newline='\n')



"""
line_1 = zeny_quote_file.readlines()
zeny_quote_lists.append(line_1)

for i in zeny_quote_lists :
    cash_daily_url_2_worksheet.append_row(i)
"""
"""
line_2 = zeny_trade_cash_file.readlines()
zeny_trade_cash_file.append(line_2)
              
for i in zeny_quote_lists :
    cash_daily_url_2_worksheet.insert_row(i)

"""
# Out:
# '\nline_2 = zeny_trade_cash_file.readlines()\nzeny_trade_cash_file.append(line_2)\n              \nfor i in zeny_quote_lists :\n    cash_daily_url_2_worksheet.insert_row(i)\n\n'

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import os
from googleapiclient.discovery import build
from httplib2 import Http
from oauth2client import file, client, tools
from googleapiclient.http import MediaFileUpload
from __future__ import print_function
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import  warnings
from    selenium import webdriver
from    selenium.webdriver.common.keys import Keys 
from    selenium.webdriver.common.action_chains import ActionChains
from    selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException
from    bs4      import BeautifulSoup
import  time
import  pyperclip
import  requests
import  datetime
import  pymssql
import  pandas as pd
import  chromedriver_autoinstaller
import  subprocess
from    selenium import webdriver
from    selenium.webdriver.chrome.options import Options
from    selenium.webdriver.common.alert import Alert
import  chromedriver_autoinstaller
import  subprocess
import  shutil 
import  xlrd
import  openpyxl 
import  pygsheets
import  csv


json_file_name = 'C:/Users/Gravity/Desktop/python/python-linkage-sample-324706-63cfc05b9800.json'

scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/spreadsheets', 
         'https://www.googleapis.com/auth/drive.file', 'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name(json_file_name, scope)
gc = gspread.authorize(credentials)

spreadsheet = gc.open('ragnarok_cash_daily')

with open('C:/Users/Gravity/Desktop/python/raw/statistics/zeny_quote_summary_20210902.csv', 'r', encoding ='utf-8') as file_obj :
    content = file_obj.read()
    content = content.replace('"', '')
    gc.import_csv(spreadsheet.id, data=content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-1d0ed3ff85ef> in <module>
#      48
#      49 with open('C:/Users/Gravity/Desktop/python/raw/statistics/zeny_quote_summary_20210902.csv', 'r', encoding ='cp949') as file_obj :
# ---> 50     content = file_obj.read(encoding='utf-8')
#      51     content = content.replace('"', '')
#      52     gc.import_csv(spreadsheet.id, data=content)
#
# TypeError: TextIOWrapper.read() takes no keyword arguments

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import os
from googleapiclient.discovery import build
from httplib2 import Http
from oauth2client import file, client, tools
from googleapiclient.http import MediaFileUpload
from __future__ import print_function
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import  warnings
from    selenium import webdriver
from    selenium.webdriver.common.keys import Keys 
from    selenium.webdriver.common.action_chains import ActionChains
from    selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException
from    bs4      import BeautifulSoup
import  time
import  pyperclip
import  requests
import  datetime
import  pymssql
import  pandas as pd
import  chromedriver_autoinstaller
import  subprocess
from    selenium import webdriver
from    selenium.webdriver.chrome.options import Options
from    selenium.webdriver.common.alert import Alert
import  chromedriver_autoinstaller
import  subprocess
import  shutil 
import  xlrd
import  openpyxl 
import  pygsheets
import  csv


json_file_name = 'C:/Users/Gravity/Desktop/python/python-linkage-sample-324706-63cfc05b9800.json'

scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/spreadsheets', 
         'https://www.googleapis.com/auth/drive.file', 'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name(json_file_name, scope)
client = gspread.authorize(credentials)

sheet = client.open('ragnarok_cash_daily') #구글스프레드시트 불러오기

sheet_instance = sheet.get_worksheet(0) #시트 가져오기

sheet_instance.cell(col=3, row=2) #특정 행 가져오기

records_data = sheet_instance.get_all_records() #시트의 모든 데이터 가져오기(json문자열로 변환)
#records_data

records_df = pd.DataFrame.from_dict(records_data)  #데이터 프레임화

sheet.add_worksheet(rows=1000, cols=24, title='test') #구글시트추가사항 정하기

sheet_runs = sheet.get_worksheet(1) #구글시트추가

sheet_runs.insert_rows(records_df.values.tolist()) #구글시트내 데이터 입력
header = list(records_df.columns) #컬럼 가져오기
index =1
sheet_runs.insert_row(header, index) #컬럼 넣기

#완료
# Out:
# {'spreadsheetId': '1gTtQZ1zEEm6lJ2nQysQfbzPU6wilUZRBqiGI-eaXSPo',
#  'updates': {'spreadsheetId': '1gTtQZ1zEEm6lJ2nQysQfbzPU6wilUZRBqiGI-eaXSPo',
#   'updatedRange': 'test!A1:K1',
#   'updatedRows': 1,
#   'updatedColumns': 11,
#   'updatedCells': 11}}
