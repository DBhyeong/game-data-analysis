# %%
import  warnings
from    selenium import webdriver
from    selenium.webdriver.common.keys import Keys 
from    selenium.webdriver.common.action_chains import ActionChains
from    selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException
from    bs4      import BeautifulSoup
import  time
import  pyperclip
import  requests
import  datetime
import  pymssql
import  pandas as pd
import  chromedriver_autoinstaller
import  subprocess
from    selenium import webdriver
from    selenium.webdriver.chrome.options import Options
from    selenium.webdriver.common.alert import Alert
import  chromedriver_autoinstaller
import  subprocess
import  shutil
import  xlrd
import  openpyxl

file = open('C:/Users/Gravity/Desktop/python/raw/input_URL.txt','r',encoding='utf-8')

urls = file.readlines()

for ar in urls :
    url = ar.replace("\n", "")
    print(url)
    
    
    
"""    
    
conn = pymssql.connect(server='localhost', user='pyuser', password='Dnflskfk12!', database='mytest' , charset='utf8', autocommit=True)

itembay_ragnarok_tmp = '''

IF OBJECT_ID('itembay_ragnarok_tmp', 'U') IS NOT NULL
DROP TABLE  itembay_ragnarok_tmp

create table mytest.dbo.itembay_ragnarok_tmp  (
game nvarchar(max) null,
server nvarchar(max) null,
is_trade_finished nvarchar(max) null,
zeny_sell_title	nvarchar(max) null,
zeny nvarchar(max) null,
cash bigint null,
regdate  nvarchar(max) null
)

select * from mytest.dbo.itembay_ragnarok_tmp with (nolock) ;  
'''

data1 = pd.read_sql(sql=itembay_ragnarok_tmp, con=conn)

conn.commit()
conn.close()

data1

"""
# Out:
# http://trade.itemmania.com/sell/view.html?id=2021081804598939
# http://trade.itemmania.com/sell/view.html?id=2021081800342627
# http://trade.itemmania.com/sell/view.html?id=2021081714008747
# http://trade.itemmania.com/sell/view.html?id=2021081713783421
# http://trade.itemmania.com/sell/view.html?id=2021081713656645
# http://trade.itemmania.com/sell/view.html?id=2021081711062236
# http://trade.itemmania.com/sell/view.html?id=2021081710874067
# http://trade.itemmania.com/sell/view.html?id=2021081710692567
# http://trade.itemmania.com/sell/view.html?id=2021081710314732
# http://trade.itemmania.com/sell/view.html?id=2021081708953433
# http://trade.itemmania.com/sell/view.html?id=2021081708362579
# http://trade.itemmania.com/sell/view.html?id=2021081707746594
# http://trade.itemmania.com/sell/view.html?id=2021081707024309
# http://trade.itemmania.com/sell/view.html?id=2021081706371440
# http://trade.itemmania.com/sell/view.html?id=2021081706137914
# ...
