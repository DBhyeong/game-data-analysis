# %%
import  warnings
from    selenium import webdriver
from    selenium.webdriver.common.keys import Keys 
from    selenium.webdriver.common.action_chains import ActionChains
from    selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException
from    bs4      import BeautifulSoup
import  time
import  pyperclip
import  requests
import  datetime
import  pymssql
import  pandas as pd
import  chromedriver_autoinstaller
import  subprocess
from    selenium import webdriver
from    selenium.webdriver.chrome.options import Options
import  chromedriver_autoinstaller
import  subprocess
import  shutil 

warnings.filterwarnings('ignore')

try:
    shutil.rmtree(r"c:\chrometemp")  #쿠키 / 캐쉬파일 삭제
except FileNotFoundError:
    pass

subprocess.Popen(r'C:\Program Files\Google\Chrome\Application\chrome.exe --remote-debugging-port=9222 --user-data-dir="C:\chrometemp"') # 디버거 크롬 구동

option = Options()
option.add_experimental_option("debuggerAddress", "127.0.0.1:9222")

chrome_ver = chromedriver_autoinstaller.get_chrome_version().split('.')[0]
try:
    driver = webdriver.Chrome(f'./{chrome_ver}/chromedriver.exe', options=option)
except:
    chromedriver_autoinstaller.install(True)
    driver = webdriver.Chrome(f'./{chrome_ver}/chromedriver.exe', options=option)
driver.implicitly_wait(10)

url = 'https://trade.itembay.com/login/loginAdult'

driver.get(url) #URL 가져오기
driver.implicitly_wait(10)

action = ActionChains(driver) #액션지정

#id, pw 입력할 곳 찾기

tag_id = driver.find_element_by_name('txtMemberID')
tag_pw = driver.find_element_by_name('txtPassword')
driver.implicitly_wait(10)

#id 입력

tag_id.click()
pyperclip.copy('id')
tag_id.send_keys(Keys.CONTROL, 'v')
driver.implicitly_wait(10)

#pw 입력

tag_pw.click()
pyperclip.copy('pw')
tag_pw.send_keys(Keys.CONTROL, 'v')
driver.implicitly_wait(10)

#로그인 버튼 클릭

login_btn = driver.find_element_by_class_name('btn_login')
login_btn.click()
time.sleep(1)
driver.implicitly_wait(10)

ragnarok_zeny_url = 'https://trade.itembay.com/item/sell/itemSellList?iGameSeq=62&iGameServerSeq=0&tiItemType=4'

driver.get(ragnarok_zeny_url)
time.sleep(1) #1초 있다가
driver.implicitly_wait(10)

page = 0


html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
results = soup.find_all("tr", {"class" : "hover_td deal_fin"})
for ar in results :
    game_server = ar.find("a", {"class" : "server_name"}).text #게임 및 서버명
    trade_results = ar.find("td", {"class": "deal_fin_ico"}).text #거래완료 여부
    zeny_selling_title = ar.find("td", {"class": "goods_name"}).text #제니판매 글 제목
    zeny = ar.td.next_sibling.next_sibling.next_sibling.text #판매제니수량
    cash = ar.td.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.text #거래가격
    date = ar.td.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.text #등록일
    print(game_server+','+ trade_results +','+ zeny_selling_title +','+ zeny  +','+  cash +','+ date)   
"""
try :
    page = page +1
    driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div[7]/div[3]/div[2]/div[3]/a['+str(page)+']').click()
except :
    print("수집완료, end")
    break
"""
#driver.close()   


"""
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
results = soup.find_all("tr", {"class" : "hover_td deal_fin"})
for ar in results :
    game_server = ar.find("a", {"class" : "server_name"}).text #게임 및 서버명
    trade_results = ar.find("td", {"class": "deal_fin_ico"}).text #거래완료 여부
    zeny_selling_title = ar.find("td", {"class": "goods_name"}).text #제니판매 글 제목
    zeny = ar.td.next_sibling.next_sibling.next_sibling.text #판매제니수량
    cash = ar.td.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.text #거래가격
    date = ar.td.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.text #등록일
    print(game_server+','+ trade_results +','+ zeny_selling_title +','+ zeny  +','+  cash +','+ date)   
    try :
        page = page +1
        driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div[7]/div[3]/div[2]/div[3]/a['+str(page)+']').click()
    except :
        print("수집완료, end")
        break
"""
# Out:
#  라그나로크 - 바포메트 ,거래완료,102억 제니 분할 판매합니다. (개인머니, 템판..,10억,300,000원  ,3시간전
#  라그나로크 - 바포메트 ,거래완료,개인 10 억 팜니다(풀인증 200% 확인!!),10억,298,000원  ,6시간전
#  라그나로크 - 바포메트 ,거래완료,♥♥♥300%안전 안전제니 팝니다★스피드거래♥..,3억,84,000원  ,17시간전
#  라그나로크 - 바포메트 ,거래완료,풀인증 사거리 안전제니 접속중 대기 신용,1억,32,000원  ,19시간전
#  라그나로크 - 바포메트 ,거래완료,순수 사냥해서 모은 제니팝니다.,10억,290,000원  ,19시간전
#  라그나로크 - 바포메트 ,거래완료,5억 제니 일괄 판매합니다.,5억,145,000원  ,19시간전
#  라그나로크 - 바포메트 ,거래완료,순수 사냥해서 모은 제니팝니다.,10억,290,000원  ,19시간전
#  라그나로크 - 바포메트 ,거래완료,5억제니 팔아요~ 순수 앵벌제니,5억,150,000원  ,20시간전
#  라그나로크 - 바포메트 ,거래완료,●^_^●━━━━(眞)☞안전금화★빠른거래☜━..,2억,57,600원  ,22시간전
#  라그나로크 - 바포메트 ,거래완료,200% 풀인증 안전제니 팝니다.,13억,377,000원  ,08/12
#  라그나로크 - 바포메트 ,거래완료,5억 제니 일괄 판매합니다.,5억,145,000원  ,08/12
#  라그나로크 - 바포메트 ,거래완료,10억 제니 일괄 판매합니다.,10억,290,000원  ,08/12
#  라그나로크 - 바포메트 ,거래완료,크아앙~!! 개인 제니 팔아용~!! (빠른거래 가능..,12억,360,000원  ,08/12
#  라그나로크 - 바포메트 ,거래완료,■■■■■▶ 정말안전한제니★ 24시즉시거래◀..,1억3,000만,49,400원  ,08/12
#  라그나로크 - 바포메트 ,거래완료,200% 풀인증 안전제니 팝니다.,13억,377,000원  ,08/12
#  라그나로크 - 바포메트 ,거래완료,서구,1억,12,000원  ,08/12
#  라그나로크 - 바포메트 ,거래완료,서구니,11억,1,417,500원  ,08/12
#  라그나로크 - 바포메트 ,거래완료,◆ 200%인증 ◆ [접속중] 안전제니 팝니다,2억2,000만,70,180원  ,08/12
#  라그나로크 - 바포메트 ,거래완료,♥♥♥300%안전 안전제니 팝니다★스피드거래♥..,2억,56,000원  ,08/12
#  라그나로크 - 바포메트 ,거래완료,♥♥♥300%안전 안전제니 팝니다★스피드거래♥..,1억,28,000원  ,08/12
#  라그나로크 - 이그드라실 ,거래완료,7억 제니 분할 판매합니다.,3억,279,000원  ,08/11
#  라그나로크 - 바포메트 ,거래완료,크아앙~!! 개인 제니 팔아용~!! (빠른거래 가능..,2억,60,000원  ,08/11
# '\nhtml = driver.page_source\nsoup = BeautifulSoup(html, \'html.parser\')\nresults = soup.find_all("tr", {"class" : "hover_td deal_fin"})\nfor ar in results :\n    game_server = ar.find("a", {"class" : "server_name"}).text #게임 및 서버명\n    trade_results = ar.find("td", {"class": "deal_fin_ico"}).text #거래완료 여부\n    zeny_selling_title = ar.find("td", {"class": "goods_name"}).text #제니판매 글 제목\n    zeny = ar.td.next_sibling.next_sibling.next_sibling.text #판매제니수량\n    cash = ar.td.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.text #거래가격\n    date = ar.td.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.text #등록일\n    print(game_server+\',\'+ trade_results +\',\'+ zeny_selling_title +\',\'+ zeny  +\',\'+  cash +\',\'+ date)   \n    try :\n        page = page +1\n        driver.find_element_by_xpath(\'/html/body/div[2]/div[2]/div[1]/div[7]/div[3]/div[2]/div[3]/a[\'+str(page)+\']\').click()\n    except :\n        print("수집완료, end")\n        break\n'
