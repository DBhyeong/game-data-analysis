# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import os
from googleapiclient.discovery import build
from httplib2 import Http
from oauth2client import file, client, tools
from googleapiclient.http import MediaFileUpload
from __future__ import print_function
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import  warnings
from    selenium import webdriver
from    selenium.webdriver.common.keys import Keys 
from    selenium.webdriver.common.action_chains import ActionChains
from    selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException
from    bs4      import BeautifulSoup
import  time
import  pyperclip
import  requests
import  datetime
import  pymssql
import  pandas as pd
import  chromedriver_autoinstaller
import  subprocess
from    selenium import webdriver
from    selenium.webdriver.chrome.options import Options
from    selenium.webdriver.common.alert import Alert
import  chromedriver_autoinstaller
import  subprocess
import  shutil 
import  xlrd
import  openpyxl 
import  pygsheets
import  csv

json_file_name = 'C:/Users/Gravity/Desktop/python/python-linkage-sample-324706-63cfc05b9800.json'

scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/spreadsheets', 
         'https://www.googleapis.com/auth/drive.file', 'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name(json_file_name, scope)
client = gspread.authorize(credentials)

ragnarok_cash_daily_google_docs = client.open('ragnarok_cash_daily') #구글스프레드시트 불러오기

zeny_quote_sheet = ragnarok_cash_daily_google_docs.get_worksheet(0) #제니시세 시트 가져오기
zeny_trade_sheet = ragnarok_cash_daily_google_docs.get_worksheet(1) #제니시세 시트 가져오기

zeny_quote_sheet.clear() #제니시세 시트 다 지우기
zeny_trade_sheet.clear() #제니거래량 시트 다 지우기

#sheet_instance.cell(col=3, row=2) #특정 행 가져오기

#records_data = sheet_instance.get_all_records() #시트의 모든 데이터 가져오기(json문자열로 변환)
#records_data

now = datetime.datetime.now() #오늘날짜
nowDate = now.strftime('%Y%m%d') #오늘날짜변환

zeny_quote_df = pd.read_csv('C:/Users/Gravity/Desktop/python/raw/statistics/zeny_quote_summary_' + str(nowDate) +'.csv') #제니시세 csv파일 열기
zeny_trade_df = pd.read_csv('C:/Users/Gravity/Desktop/python/raw/statistics/zeny_trade_cash_summary_'+str(nowDate)+'.csv') #제니거래량 csv파일 열기

#sheet.add_worksheet(rows=1000, cols=24, title='cash') #구글시트추가사항 정하기

#sheet_runs = sheet.get_worksheet(1) #구글시트추가

#제니시세 구글독스에 데이터 입력

zeny_quote_sheet.insert_rows(zeny_quote_df.values.tolist()) #구글시트내 데이터 입력
header_1 = list(zeny_quote_df.columns) #컬럼 가져오기
index_1 =1
zeny_quote_sheet.insert_row(header_1, index_1) #컬럼 넣기

#제니거래량 구글독스에 데이터 입력

zeny_trade_sheet.insert_rows(zeny_trade_df.values.tolist()) #구글시트내 데이터 입력
header_2 = list(zeny_trade_df.columns) #컬럼 가져오기
index_2 =1
zeny_trade_sheet.insert_row(header_2, index_2) #컬럼 넣기

#완료
# Out:
# {'spreadsheetId': '1gTtQZ1zEEm6lJ2nQysQfbzPU6wilUZRBqiGI-eaXSPo',
#  'updates': {'spreadsheetId': '1gTtQZ1zEEm6lJ2nQysQfbzPU6wilUZRBqiGI-eaXSPo',
#   'updatedRange': "'제니거래량'!A1:K1",
#   'updatedRows': 1,
#   'updatedColumns': 11,
#   'updatedCells': 11}}

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import os
from googleapiclient.discovery import build
from httplib2 import Http
from oauth2client import file, client, tools
from googleapiclient.http import MediaFileUpload
from __future__ import print_function
import pickle
import os.path
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import  warnings
from    selenium import webdriver
from    selenium.webdriver.common.keys import Keys 
from    selenium.webdriver.common.action_chains import ActionChains
from    selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException
from    bs4      import BeautifulSoup
import  time
import  pyperclip
import  requests
import  datetime
import  pymssql
import  pandas as pd
import  chromedriver_autoinstaller
import  subprocess
from    selenium import webdriver
from    selenium.webdriver.chrome.options import Options
from    selenium.webdriver.common.alert import Alert
import  chromedriver_autoinstaller
import  subprocess
import  shutil 
import  xlrd
import  openpyxl 
import  pygsheets
import  csv

json_file_name = 'C:/Users/Gravity/Desktop/python/python-linkage-sample-324706-63cfc05b9800.json'

scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/spreadsheets', 
         'https://www.googleapis.com/auth/drive.file', 'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name(json_file_name, scope)
client = gspread.authorize(credentials)

sheet = client.open('ragnarok_cash_daily') #구글스프레드시트 불러오기

sheet_instance = sheet.get_worksheet(0) #시트 가져오기

sheet_instance.cell(col=3, row=2) #특정 행 가져오기

records_data = sheet_instance.get_all_records() #시트의 모든 데이터 가져오기(json문자열로 변환)
#records_data

records_df = pd.DataFrame.from_dict(records_data)  #데이터 프레임화

sheet.add_worksheet(rows=1000, cols=24, title='test') #구글시트추가사항 정하기

sheet_runs = sheet.get_worksheet(1) #구글시트추가

sheet_runs.insert_rows(records_df.values.tolist()) #구글시트내 데이터 입력
header = list(records_df.columns) #컬럼 가져오기
index =1
sheet_runs.insert_row(header, index) #컬럼 넣기

#완료
