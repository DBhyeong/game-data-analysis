# %%
import  warnings
from    selenium import webdriver
from    selenium.webdriver.common.keys import Keys 
from    selenium.webdriver.common.action_chains import ActionChains
from    selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException
from    bs4      import BeautifulSoup
import  time
import  pyperclip
import  requests
import  datetime
import  pymssql
import  pandas as pd
import  chromedriver_autoinstaller
import  subprocess
from    selenium import webdriver
from    selenium.webdriver.chrome.options import Options
import  chromedriver_autoinstaller
import  subprocess
import  shutil 

warnings.filterwarnings('ignore')

try:
    shutil.rmtree(r"c:\chrometemp")  #쿠키 / 캐쉬파일 삭제
except FileNotFoundError:
    pass

subprocess.Popen(r'C:\Program Files\Google\Chrome\Application\chrome.exe --remote-debugging-port=9222 --user-data-dir="C:\chrometemp"') # 디버거 크롬 구동

option = Options()
option.add_experimental_option("debuggerAddress", "127.0.0.1:9222")

chrome_ver = chromedriver_autoinstaller.get_chrome_version().split('.')[0]
try:
    driver = webdriver.Chrome(f'./{chrome_ver}/chromedriver.exe', options=option)
except:
    chromedriver_autoinstaller.install(True)
    driver = webdriver.Chrome(f'./{chrome_ver}/chromedriver.exe', options=option)
driver.implicitly_wait(10)

url = 'https://trade.itembay.com/login/loginAdult'

driver.get(url) #URL 가져오기
driver.implicitly_wait(10)

action = ActionChains(driver) #액션지정

#id, pw 입력할 곳 찾기

tag_id = driver.find_element_by_name('txtMemberID')
tag_pw = driver.find_element_by_name('txtPassword')
driver.implicitly_wait(10)

#id 입력

tag_id.click()
pyperclip.copy('id')
tag_id.send_keys(Keys.CONTROL, 'v')
driver.implicitly_wait(10)

#pw 입력

tag_pw.click()
pyperclip.copy('pw')
tag_pw.send_keys(Keys.CONTROL, 'v')
driver.implicitly_wait(10)

#로그인 버튼 클릭

login_btn = driver.find_element_by_class_name('btn_login')
login_btn.click()
time.sleep(1)
driver.implicitly_wait(10)

ragnarok_zeny_url = 'https://trade.itembay.com/item/sell/itemSellList?iGameSeq=62&iGameServerSeq=0&tiItemType=4'

driver.get(ragnarok_zeny_url)
time.sleep(1) #1초 있다가
driver.implicitly_wait(10)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

maximum = 0
page = 1

while 1:
    page_list = soup.find_all("a", {"id" : "btnPaging" + str(page)})
    if not page_list :
        maximum = page - 1
        break
    page = page + 1


for page in range(1, maximum+1) :
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    results = soup.find_all("tr", {"class" : "hide_td"})
    for ar in results :
        trade_id = ar.find('input', {'type' : 'hidden'}).get('value') #거래번호
        url = 'https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=' + str(trade_id)
        print(url)
    try :
        page = page +1
        driver.find_element_by_xpath('//*[@id="btnPaging'+str(page)+'"]').click()
        driver.implicitly_wait(10)
    except :
        print("end")
        break

#driver.close()   


#max_page까지 URL 긁기 완료
# Out:
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25331879209
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25331876733
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25331876621
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25331875845
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25331875234
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25331874429
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25331871282
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25331870801
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25331865957
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25331863071
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25331863030
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25331854814
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25331847941
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25331847903
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25331666550
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25331597925
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25331004212
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25330571237
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25330540614
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25330425032
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25330408459
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25329994895
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25329864834
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25328859916
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25328139627
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25328007844
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25327624615
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25327573266
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25327533336
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25327476953
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25327171077
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25326791526
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25326110831
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25325721640
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25325720022
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25325670790
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25325583204
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25325399489
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25325348941
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25324365187
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25324341113
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25324336356
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25323394954
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25322959042
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25322392560
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25322151931
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25322091244
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25322090855
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25322075096
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25321910218
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25321666848
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25321473678
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25321324727
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25321297270
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25320730216
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25320697261
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25320517376
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25319944899
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25319897934
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25319678872
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25319452109
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25319242688
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25318972167
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25318430090
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25317028042
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25317022555
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25316618411
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25316097482
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25315710764
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25315406035
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25315388500
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25315081350
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25315041679
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25314960451
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25314225953
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25313107010
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25312907040
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25312687526
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25312366059
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25312233897
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25312150513
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25312037740
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25311823636
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25311692753
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25311172351
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25311126042
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25310872812
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25310615723
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25310550058
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25310268507
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25309829184
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25309531670
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25309390943
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25309198362
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25308706908
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25307930018
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25307382890
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25307079655
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25307054104
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25306981536
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25306270332
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25306250559
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25306105146
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25305994062
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25305977319
# https://trade.itembay.com/item/sell/itemSellDetail?iItemSeq=25305933855
# end
